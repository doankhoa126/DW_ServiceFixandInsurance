# %%
import csv
import random

with open('CSVNOTE1.csv',"r",encoding ='utf8') as csv_file:
    csv_reader = csv.DictReader(csv_file)
    next(csv_reader)
    for row in csv_reader:
        InsuranceStatus_ID= row['InsuranceStatus_ID']
        Product_ID= row['Product_ID']
        Customer_ID= row['Customer_ID']
        InsuranceStatus_Name= row['InsuranceStatus_Name']
        Insurance_Time = row['Insurance_Time']
        Insurance_Time_Start = row['Insurance_Time_Start']
        Insurance_Time_Now = row['Insurance_Time_Now']
        Supplier_ID = row['Supplier_ID']
        Receipt_ID = row['Receipt_ID']   
        ProductType_ID = row['ProductType_ID']
        Component_ID = row['Component_ID']
        Price = row['Price']
        Receive_Device_Time = row['Receive_Device_Time']
        Series = row['Series']
        Total_Cash = row['Total_Cash']
        Service_ID = row['Service_ID']
        Total_Repair_Time = row['Total_Repair_Time']
        Deliver_Device_Time = row['Deliver_Device_Time']
        Review_ID = row['Review_ID']
        Series = row['Series']
        
    
        query = "Insert Into Insurance_Status(InsuranceStatus_ID,Product_ID,Customer_ID,Series,InsuranceStatus_Name,Insurance_Time,Insurance_Time_Start) values('{InsuranceStatus_ID}','{Product_ID}','{Customer_ID}','{Series}',N'{InsuranceStatus_Name}','{Insurance_Time}','{Insurance_Time_Start}');".format(InsuranceStatus_ID=InsuranceStatus_ID,Product_ID=Product_ID,Customer_ID=Customer_ID ,Series=Series,InsuranceStatus_Name=InsuranceStatus_Name, Insurance_Time = Insurance_Time, Insurance_Time_Start = Insurance_Time_Start)
        print(query)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8432\3942679990.py in <module>
#      13         Insurance_Time_Start = row['Insurance_Time_Start']
#      14         Insurance_Time_Now = row['Insurance_Time_Now']
# ---> 15         Supplier_ID = row['Supplier_ID']
#      16         Receipt_ID = row['Receipt_ID']
#      17         ProductType_ID = row['ProductType_ID']
#
# KeyError: 'Supplier_ID'

# %%
import csv
import random

with open('CSVNOTE1.csv',"r",encoding ='utf8') as csv_file:
    csv_reader = csv.DictReader(csv_file)
    next(csv_reader)
    for row in csv_reader:
        InsuranceStatus_ID= row['InsuranceStatus_ID']
        Product_ID= row['Product_ID']
        Customer_ID= row['Customer_ID']
        InsuranceStatus_Name= row['InsuranceStatus_Name']
        Insurance_Time = row['Insurance_Time']
        Insurance_Time_Start = row['Insurance_Time_Start']
        Insurance_Time_Now = row['Insurance_Time_Now']
        Receipt_ID = row['Receipt_ID']   
        Component_ID = row['Component_ID']
        Price = row['Price']
        Receive_Device_Time = row['Receive_Device_Time']
        Series = row['Series']
        Total_Cash = row['Total_Cash']
        Service_ID = row['Service_ID']
        Total_Repair_Time = row['Total_Repair_Time']
        Deliver_Device_Time = row['Deliver_Device_Time']
        Series = row['Series']
        
    
        query = "Insert Into Insurance_Status(InsuranceStatus_ID,Product_ID,Customer_ID,Series,InsuranceStatus_Name,Insurance_Time,Insurance_Time_Start) values('{InsuranceStatus_ID}','{Product_ID}','{Customer_ID}','{Series}',N'{InsuranceStatus_Name}','{Insurance_Time}','{Insurance_Time_Start}');".format(InsuranceStatus_ID=InsuranceStatus_ID,Product_ID=Product_ID,Customer_ID=Customer_ID ,Series=Series,InsuranceStatus_Name=InsuranceStatus_Name, Insurance_Time = Insurance_Time, Insurance_Time_Start = Insurance_Time_Start)
        print(query)
# Out:
# Insert Into Insurance_Status(InsuranceStatus_ID,Product_ID,Customer_ID,Series,InsuranceStatus_Name,Insurance_Time,Insurance_Time_Start) values('Insu102','Prt1309','Cus114410','Sers302',N'Còn bảo hành ','1','2022-02-07');
# Insert Into Insurance_Status(InsuranceStatus_ID,Product_ID,Customer_ID,Series,InsuranceStatus_Name,Insurance_Time,Insurance_Time_Start) values('Insu103','Prt1309','Cus697828','Sers303',N'Còn bảo hành ','1','2022-03-17');
# Insert Into Insurance_Status(InsuranceStatus_ID,Product_ID,Customer_ID,Series,InsuranceStatus_Name,Insurance_Time,Insurance_Time_Start) values('Insu104','Prt1318','Cus116886','Sers304',N'Còn bảo hành ','3','2022-03-25');
# Insert Into Insurance_Status(InsuranceStatus_ID,Product_ID,Customer_ID,Series,InsuranceStatus_Name,Insurance_Time,Insurance_Time_Start) values('Insu105','Prt1329','Cus700591','Sers305',N'Còn bảo hành ','2','2022-04-24');
# ...
