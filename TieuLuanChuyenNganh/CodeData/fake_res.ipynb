# %%
import csv
import random
Staff_ID_list=["St457","St458","St460","St465","St466","St468","St469","St476","St482","St490","St491","St493","St500","St503","St510","St511","St518","St519","St530","St533","St537","St538","St539","St540","St541","St547"]
list_poy =["Chuyển khoản","Tiền mặt"]
list_null=["Null"]

with open('new5.csv',"r") as csv_file:
    csv_reader = csv.DictReader(csv_file)
    next(csv_reader)
    for row in csv_reader:
        InsuranceStatus_ID= row['InsuranceStatus_ID']
        Product_ID= row['Product_ID']
        Customer_ID= row['Customer_ID']
        InsuranceStatus_Name= row['InsuranceStatus_Name']
        Insurance_Time = row['Insurance_Time']
        Insurance_Time_Start = row['Insurance_Time_Start']
        Insurance_Time_Now = row['Insurance_Time_Now']
        Supplier_ID = row['Supplier_ID']
        Receipt_ID = row['Receipt_ID']
        ProductType_ID = row['ProductType_ID']
        Component_ID = row['Component_ID']
        Price = row['Price']
        Receive_Device_Time = row['Receive_Device_Time']
        Total_Cash = row['Total_Cash']
        Service_ID = row['Service_ID']
        Total_Repair_Time = row['Total_Repair_Time']
        Deliver_Device_Time = row['Deliver_Device_Time']
    
        Staff_ID=random.choice(Staff_ID_list)
        Payments=random.choice(list_poy)

        query = "Insert Into Receipt(Receipt_ID,Staff_ID,Customer_ID,Product_ID,Service_ID,Component_ID,InsuranceStatus_ID,Receive_Device_Time,Deliver_Device_Time,Total_Repair_Time,Payments,Total_Cash) values('{Receipt_ID}','{Staff_ID}','{Customer_ID}','{Product_ID}','{Service_ID}','{Component_ID}','{InsuranceStatus_ID}','{Receive_Device_Time}','{Deliver_Device_Time}',{Total_Repair_Time},N'{Payments}',{Total_Cash});".format(Receipt_ID=Receipt_ID,Staff_ID=Staff_ID,Customer_ID=Customer_ID,Product_ID=Product_ID,Service_ID=Service_ID,Component_ID=Component_ID,InsuranceStatus_ID=InsuranceStatus_ID,Receive_Device_Time=Receive_Device_Time,Deliver_Device_Time=Deliver_Device_Time,Total_Repair_Time=Total_Repair_Time,Payments=Payments,Total_Cash=Total_Cash)

        print(query)
# Out:
# Insert Into Receipt(Receipt_ID,Staff_ID,Customer_ID,Product_ID,Service_ID,Component_ID,InsuranceStatus_ID,Receive_Device_Time,Deliver_Device_Time,Total_Repair_Time,Payments,Total_Cash) values('Rec15640','St500','Cus150347','Prt228','Sv02','Cnt691','Ins15641','2022-08-08','2022-08-15',7,N'Chuyển khoản',2150000);
# Insert Into Receipt(Receipt_ID,Staff_ID,Customer_ID,Product_ID,Service_ID,Component_ID,InsuranceStatus_ID,Receive_Device_Time,Deliver_Device_Time,Total_Repair_Time,Payments,Total_Cash) values('Rec15651','St510','Cus150687','Prt229','Sv02','Cnt699','Ins15652','2022-09-26','2022-10-03',7,N'Tiền mặt',2150000);
# Insert Into Receipt(Receipt_ID,Staff_ID,Customer_ID,Product_ID,Service_ID,Component_ID,InsuranceStatus_ID,Receive_Device_Time,Deliver_Device_Time,Total_Repair_Time,Payments,Total_Cash) values('Rec12664','St457','Cus86562','Prt230','Sv02','Cnt727','Ins12665','2022-10-11','2022-10-18',7,N'Tiền mặt',2150000);
# ...

# %%
import csv
import random
Staff_ID_list=["St457","St458","St460","St465","St466","St468","St469","St476","St482","St490","St491","St493","St500","St503","St510","St511","St518","St519","St530","St533","St537","St538","St539","St540","St541","St547"]
list_poy =["Chuyển khoản","Tiền mặt"]
list_null=["Null"]

with open('CSVNOTE1.csv',"r") as csv_file:
    csv_reader = csv.DictReader(csv_file)
    next(csv_reader)
    for row in csv_reader:
        InsuranceStatus_ID= row['InsuranceStatus_ID']
        Product_ID= row['Product_ID']
        Customer_ID= row['Customer_ID']
        InsuranceStatus_Name= row['InsuranceStatus_Name']
        Insurance_Time = row['Insurance_Time']
        Insurance_Time_Start = row['Insurance_Time_Start']
        Insurance_Time_Now = row['Insurance_Time_Now']
        Receipt_ID = row['Receipt_ID']   
        Component_ID = row['Component_ID']
        Price = row['Price']
        Receive_Device_Time = row['Receive_Device_Time']
        Series = row['Series']
        Total_Cash = row['Total_Cash']
        Service_ID = row['Service_ID']
        Total_Repair_Time = row['Total_Repair_Time']
        Deliver_Device_Time = row['Deliver_Device_Time']
        Series = row['Series']
    
        Staff_ID=random.choice(Staff_ID_list)
        Payments=random.choice(list_poy)

        query = "Insert Into Receipt(Receipt_ID,Staff_ID,Customer_ID,Product_ID,Service_ID,Component_ID,InsuranceStatus_ID,Receive_Device_Time,Deliver_Device_Time,Total_Repair_Time,Payments,Total_Cash) values('{Receipt_ID}','{Staff_ID}','{Customer_ID}','{Product_ID}','{Service_ID}','{Component_ID}','{InsuranceStatus_ID}','{Receive_Device_Time}','{Deliver_Device_Time}',{Total_Repair_Time},N'{Payments}',{Total_Cash});".format(Receipt_ID=Receipt_ID,Staff_ID=Staff_ID,Customer_ID=Customer_ID,Product_ID=Product_ID,Service_ID=Service_ID,Component_ID=Component_ID,InsuranceStatus_ID=InsuranceStatus_ID,Receive_Device_Time=Receive_Device_Time,Deliver_Device_Time=Deliver_Device_Time,Total_Repair_Time=Total_Repair_Time,Payments=Payments,Total_Cash=Total_Cash)

        print(query)
# Out:
# Insert Into Receipt(Receipt_ID,Staff_ID,Customer_ID,Product_ID,Service_ID,Component_ID,InsuranceStatus_ID,Receive_Device_Time,Deliver_Device_Time,Total_Repair_Time,Payments,Total_Cash) values('Rect982','St510','Cus114410','Prt1309','Sv01','Cnt142','Insu102','2022-06-23','2022-06-26',3,N'Tiền mặt',0);
# Insert Into Receipt(Receipt_ID,Staff_ID,Customer_ID,Product_ID,Service_ID,Component_ID,InsuranceStatus_ID,Receive_Device_Time,Deliver_Device_Time,Total_Repair_Time,Payments,Total_Cash) values('Rect983','St460','Cus697828','Prt1309','Sv01','Cnt243','Insu103','2022-08-16','2022-08-19',3,N'Chuyển khoản',0);
# Insert Into Receipt(Receipt_ID,Staff_ID,Customer_ID,Product_ID,Service_ID,Component_ID,InsuranceStatus_ID,Receive_Device_Time,Deliver_Device_Time,Total_Repair_Time,Payments,Total_Cash) values('Rect984','St491','Cus116886','Prt1318','Sv01','Cnt65','Insu104','2022-09-28','2022-10-01',3,N'Chuyển khoản',0);
# ...
