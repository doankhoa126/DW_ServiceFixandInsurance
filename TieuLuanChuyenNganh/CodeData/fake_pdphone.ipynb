# %%
import csv
import random 
product = {}
#def read_csv():
list_cpu=['Exynos 9810','Exynos 8895',' Exynos 7885',' Exynos 7870','Snapdragon 710','Snapdragon 426','Snapdragon 845','Snapdragon 835','Kirin','MediaTek Helio P22','MediaTek Helio P60','MediaTek Helio P70','MediaTek Helio P90','MediaTek Helio P95','MediaTek Dimensity 800','Snapdragon 765G','Snapdragon 768G','MediaTek Dimensity 820','Snapdragon 855','Snapdragon 888','Snapdragon 712','Snapdragon 720G','Snapdragon 768G','Snapdragon 626','Snapdragon 636','Snapdragon 675','Snapdragon 439','Snapdragon 215']
list_cpuaplle=['Apple A4','Apple A13 Bionic','Apple A5','Apple A5X','Apple A6','Apple A6X',' Apple A7','Apple A8','Apple A9','Apple A10','Apple A11']

list_Ram=['2GB','4GB','3GB','8GB']
list_ins=['1','2']
with open('phones_datas1.csv',"rt") as csv_file:
    
    csv_reader = csv.DictReader(csv_file)
    next(csv_reader)
    for row in csv_reader:
        Product_ID= row['Product_ID']
        Supplier_ID= row['Supplier_ID']
        ProductType_ID= row['ProductType_ID']
        Product_Name= row['Product_Name']
        OS = row['OS']
        Screen = row['Screen']   
        Memory = row['Memory']
        Price = row['Price']
        
        id_Product =f'Prt{Product_ID}'
        Ram =random.choice(list_Ram)
        CPU=random.choice(list_cpuaplle)
        Insurance_Time=random.choice(list_ins)
        query = "Insert Into Dim_Product(Product_ID,Supplier_ID,ProductType_ID,Product_Name,OS,Screen,CPU,Ram,Memory,Price,Insurance_Time) values('{Product_ID}','{Supplier_ID}','{ProductType_ID}','{Product_Name}','{OS}','{Screen}','{CPU}','{Ram}','{Memory}',{Price},{Insurance_Time});".format(Product_ID=id_Product,Supplier_ID=Supplier_ID,ProductType_ID=ProductType_ID ,Product_Name=Product_Name, OS = OS, Screen = Screen, CPU=CPU,Ram=Ram,Memory=Memory,Price=Price,Insurance_Time=Insurance_Time)
        print(query)
# Out:
# Insert Into Dim_Product(Product_ID,Supplier_ID,ProductType_ID,Product_Name,OS,Screen,CPU,Ram,Memory,Price,Insurance_Time) values('Prt2','Sup15','PT01','1 5033D 1/16GB Volcano Black (5033D-2LALUAF)','Android','5','Apple A13 Bionic','8GB','16',1803,1);
# Insert Into Dim_Product(Product_ID,Supplier_ID,ProductType_ID,Product_Name,OS,Screen,CPU,Ram,Memory,Price,Insurance_Time) values('Prt3','Sup15','PT01','1 5033D 1/16GB Volcano Black (5033D-2LALUAF)','Android','5','Apple A11','3GB','16',1803,1);
# Insert Into Dim_Product(Product_ID,Supplier_ID,ProductType_ID,Product_Name,OS,Screen,CPU,Ram,Memory,Price,Insurance_Time) values('Prt4','Sup15','PT01','1 5033D 1/16GB Volcano Black (5033D-2LALUAF)','Android','5','Apple A4','4GB','16',1803,1);
# Insert Into Dim_Product(Product_ID,Supplier_ID,ProductType_ID,Product_Name,OS,Screen,CPU,Ram,Memory,Price,Insurance_Time) values('Prt5','Sup65','PT01','1.3 1/16GB Charcoal','Android','5.71','Apple A5','8GB','16',1999,2);
# ...
