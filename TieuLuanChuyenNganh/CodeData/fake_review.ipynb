# %%
import random
import unidecode
import csv

des = ["Rất không hài lòng","Không hài lòng","Bình Thường","Khá hài lòng","Rất hài lòng"]
with open('cusx.csv',"rt", encoding="utf-8") as csv_file: 
    csv_reader = csv.DictReader(csv_file)
    next(csv_reader)
    for row in csv_reader:
        Customer_ID= row['Customer_ID']
        Customer_FullName= row['Customer_FullName']
        Address= row['Address']
        Phone_Number = row['Phone_Number']
        Email = row['Email']   
        Rating = random.choice(list_rate)
        Review =random.randint(1,5500) 
        Review_ID=f'Rev{Review}'
        DescriptionRating=random.choice(des)
        query = "Insert Into Review(Review_ID,Customer_ID,DescriptionRating) values('{Review_ID}','{Customer_ID}',N'{DescriptionRating}');".format(Review_ID=Review_ID ,Customer_ID=Customer_ID, DescriptionRating = DescriptionRating)
        print(query)
# Out:
# Insert Into Review(Review_ID,Customer_ID,DescriptionRating) values('Rev4681','Cus1001',N'Không hài lòng');
# Insert Into Review(Review_ID,Customer_ID,DescriptionRating) values('Rev500','Cus100156',N'Bình Thường');
# Insert Into Review(Review_ID,Customer_ID,DescriptionRating) values('Rev2901','Cus100261',N'Rất không hài lòng');
# Insert Into Review(Review_ID,Customer_ID,DescriptionRating) values('Rev3445','Cus100263',N'Rất hài lòng');
# Insert Into Review(Review_ID,Customer_ID,DescriptionRating) values('Rev4994','Cus100276',N'Rất hài lòng');
# Insert Into Review(Review_ID,Customer_ID,DescriptionRating) values('Rev4580','Cus100352',N'Rất không hài lòng');
# Insert Into Review(Review_ID,Customer_ID,DescriptionRating) values('Rev1418','Cus100400',N'Không hài lòng');
# Insert Into Review(Review_ID,Customer_ID,DescriptionRating) values('Rev3992','Cus100447',N'Rất không hài lòng');
# Insert Into Review(Review_ID,Customer_ID,DescriptionRating) values('Rev3309','Cus100578',N'Rất hài lòng');
# ...

# %%
for num in range(1,15000):
    idcus =random.randint(1, 999999)
